# %%
import torch as torch
import torch.nn as nn
import numpy as np
import math

# %% [markdown]
# 3-layers CNN network

# %%
class CNN_beseline(nn.Module):
    def __init__(self):
        super(CNN_beseline, self).__init__()
        self.batch_size = 100
        conv_kernel_size = 8
        pool_kernel_size = 4
        nkernels = [320,480,960]
        
        sequence_length =  1000
        n_genomic_features  = 919
 
        self.cnn_layer1 = nn.Sequential(
            nn.Conv1d(4, nkernels[0], kernel_size = conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=pool_kernel_size, stride=pool_kernel_size),
            nn.Dropout(p=0.2)
        )
        self.cnn_layer2 = nn.Sequential(
            nn.Conv1d(nkernels[0], nkernels[1], kernel_size = conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(kernel_size=pool_kernel_size, stride=pool_kernel_size),
            nn.Dropout(0.2)
        )
        self.cnn_layer3 = nn.Sequential(    
            nn.Conv1d(nkernels[1], nkernels[2], kernel_size = conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5)
            )
        
        
        reduce_by = conv_kernel_size - 1
        pool_kernel_size = float(pool_kernel_size)
        self.n_channels = int(
            np.floor(
                (np.floor(
                    (sequence_length - reduce_by) / pool_kernel_size)
                 - reduce_by) / pool_kernel_size)
            - reduce_by)
        
        self.classifier = nn.Sequential(
            nn.Linear(960 * self.n_channels, n_genomic_features),
            nn.ReLU(inplace=True),
            nn.Linear(n_genomic_features, n_genomic_features),
            nn.Sigmoid())
        
        params = self.parameters()
        self.optimizer = torch.optim.Adam(params,lr = 0.001)

    def forward(self, x):

        out = self.cnn_layer1(x)
        out = self.cnn_layer2(out)
        out = self.cnn_layer3(out)
        #print("out.shape: ",out.shape)
        reshape_out = out.reshape(out.size(0), 960 * self.n_channels)
        predict = self.classifier(reshape_out)
        return predict

  
        return out

# %% [markdown]
# Train

# %%
def train(model, train_inputs, train_labels):
    loss = nn.BCELoss()
    for i in range(int(train_inputs.shape[0]/model.batch_size)):
        train_x_batch = train_inputs[i*model.batch_size:(i+1)*model.batch_size]
        train_y_batch = train_labels[i*model.batch_size:(i+1)*model.batch_size]
        
        train_x_batch = torch.tensor(train_x_batch)
        train_y_batch = torch.tensor(train_y_batch)
        train_y_batch = train_y_batch.float()
        logits = model.forward(train_x_batch.float())
        l = loss(logits,train_y_batch)
        
        print("loss: ",l)
        model.optimizer.zero_grad()
        l.backward()
        model.optimizer.step()

# %%
def test(model, test_inputs, test_labels):
    total_loss = 0
    for i in range(int(test_inputs.shape[0]/model.batch_size)):
        test_x_batch = test_inputs[i*model.batch_size:(i+1)*model.batch_size]
        test_y_batch = test_labels[i*model.batch_size:(i+1)*model.batch_size]

        logits = model.call(test_x_batch, True)
        loss = model.loss()
        total_loss += loss
    return total_loss/int(test_inputs.shape[0]/model.batch_size)

# %% [markdown]
# Main Function

# %%
def main():
    # train label and data
    labels = np.load('./processed_data/testdata_0_10000/reshape_labels_0_10000.npy')
    data = np.load('./processed_data/testdata_0_10000/reshape_data_0_10000.npy')
    
    model = CNN_beseline()
    for i in range(1):
        print("-----------epoch "+str(i+1)+"--------------")
        train(model, data, labels)
   # print('final accuracy {}'.format(test(model, test_inputs, test_labels)))
    
    #test_input_part = test_inputs[:10]
    #test_label_part = test_labels[:10]
    #visualize_results(test_input_part, model.call(test_input_part), test_label_part, CAT, DOG)
    return

# %%
main()
# Out:
# -----------epoch 1--------------
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.6925, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.6823, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.3115, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.5960, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.3218, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.2544, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.2520, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.2226, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1272, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0781, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1527, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1408, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1765, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1691, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1697, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1758, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1562, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1349, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1423, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1456, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1375, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1611, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1258, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1494, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0952, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1099, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0777, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1094, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1968, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1718, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1555, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1130, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1098, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1224, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0679, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1493, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.2032, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1191, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0894, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0787, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0685, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0827, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0513, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0524, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1207, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0755, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0956, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0998, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0899, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0688, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1474, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0895, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0847, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1146, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1294, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1675, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0521, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0450, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0482, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0461, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0719, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0446, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0308, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0287, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0653, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0478, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0492, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0452, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0868, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1462, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1076, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0859, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1178, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1880, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1289, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0907, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1604, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1334, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0946, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1255, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1046, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1598, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1559, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1125, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1224, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0719, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0762, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0819, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0595, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0981, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0882, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0781, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0758, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0933, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0742, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0846, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1122, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.0648, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1878, grad_fn=<BinaryCrossEntropyBackward>)
# out.shape:  torch.Size([100, 960, 53])
# loss:  tensor(0.1343, grad_fn=<BinaryCrossEntropyBackward>)
